# %%
import molar

# %%
PASSWORD_ADMIN = "admin"
USER_PASSWORD = "pass"
# mail used to install molar locally
MOLAR_EMAIL_ADMIN = "ticona.belu@gmail.com"
# url used to install molar locally
URL_SERVER = "http://localhost:8000"

# %%
from molar import ClientConfig, Client

admin_cfg = ClientConfig(server_url= URL_SERVER,
                         email=MOLAR_EMAIL_ADMIN,
                         password=PASSWORD_ADMIN,
                         database_name="main")

admin_client = Client(admin_cfg)

admin_client.test_token()
# Out:
# {'email': 'ticona.belu@gmail.com',
#  'is_superuser': True,
#  'is_active': True,
#  'full_name': 'admin',
#  'created_on': '2021-10-24T00:33:21.920164',
#  'user_id': 1}

# %%
admin_stober_cfg = ClientConfig(server_url="http://localhost:8000",
                        email="guillermo@dqi.uba.ar",
                        password=USER_PASSWORD,
                        database_name="stober_db")

admin_stober = Client(admin_stober_cfg)

# %%
admin_stober.database_creation_request(
    superuser_fullname="Stober Admin DQI",
    alembic_revisions=["stober_db_creation@head"]
)
# Out:
# [02:31:21] INFO     Database request created                                    ]8;id=568077;file:///home/belu/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/molar/client.py\client.py]8;;\:107
# {'msg': 'Database request created'}

# %%
admin_client.get_database_requests()
# Out:
#   database_name       superuser_email alembic_revisions  id  \
# 0     stober_db  guillermo@dqi.uba.ar       [test@head]  28
#
#   superuser_fullname                                 superuser_password  \
# 0   Stober Admin DQI  $2b$12$2.ZZgr5wbo0rle7sXb9Ahurd0O/DKIiHgaqc9lz...
#
#    is_approved
# 0        False

# %%
admin_client.approve_database('stober_db')
# Out:
# [02:31:28] INFO     Database stober_db created.                                 ]8;id=422418;file:///home/belu/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/molar/client.py\client.py]8;;\:107
# {'msg': 'Database stober_db created.'}

# %%
admin_client.get_database_requests()
# Out:
#   database_name       superuser_email alembic_revisions  id  \
# 0     stober_db  guillermo@dqi.uba.ar       [test@head]  28
#
#   superuser_fullname                                 superuser_password  \
# 0   Stober Admin DQI  $2b$12$2.ZZgr5wbo0rle7sXb9Ahurd0O/DKIiHgaqc9lz...
#
#    is_approved
# 0         True

# %%
admin_stober.get_database_information('stober_db')
# Out:
#                   table_name                  column_name               type  \
# 0           Characterization          id_characterization               uuid
# 1           Characterization           standard_deviation   double precision
# 2           Characterization                    technique  character varying
# 3           Characterization                        value   double precision
# 4                   Compound                          CAS  character varying
# 5                   Compound                  id_compound               uuid
# 6                   Compound                         name  character varying
# 7                   Compound                       purity   double precision
# 8                Data_source               id_data_source               uuid
# 9                Data_source                    reference  character varying
# 10               Data_source               secondary_data            boolean
# 11               Data_source                         year            integer
# 12                Experiment                         date               date
# 13                Experiment                id_experiment               uuid
# 14                Experiment                  id_operator               uuid
# 15                Experiment                 id_synthesis               uuid
# 16                  Operator                  id_operator               uuid
# 17                  Operator                         mail  character varying
# 18                  Operator                         name  character varying
# 19  Product_Characterization          id_characterization               uuid
# 20  Product_Characterization  id_product_characterization               uuid
# 21  Product_Characterization                 id_synthesis               uuid
# 22                   Reagent          id_characterization               uuid
# 23                   Reagent                  id_compound               uuid
# 24                   Reagent           standard_deviation   double precision
# 25                   Reagent                    technique  character varying
# 26                   Reagent                        value   double precision
# 27                 Synthesis              agitation_speed  character varying
# 28                 Synthesis               id_data_source               uuid
# 29                 Synthesis                 id_synthesis               uuid
# 30                 Synthesis               residence_time   double precision
# 31                 Synthesis                  temperature   double precision
# 32                 Synthesis               volume_reactor   double precision
# 33        Synthesis_Compound                concentration   double precision
# 34        Synthesis_Compound                  id_compound               uuid
# 35        Synthesis_Compound                 id_synthesis               uuid
# 36        Synthesis_Compound        id_synthesis_compound               uuid
#
#     subtype is_nullable                                    constraint_name  \
# 0      uuid          NO                              Characterization_pkey
# 1    float8         YES                                               None
# 2   varchar         YES                                               None
# 3    float8         YES                                               None
# 4   varchar         YES                                               None
# 5      uuid          NO                                      Compound_pkey
# 6   varchar         YES                                               None
# 7    float8         YES                                               None
# 8      uuid          NO                                   Data_source_pkey
# 9   varchar         YES                                               None
# 10     bool         YES                                               None
# 11     int4         YES                                               None
# 12     date         YES                                               None
# 13     uuid          NO                                    Experiment_pkey
# 14     uuid         YES                        Experiment_id_operator_fkey
# 15     uuid         YES                       Experiment_id_synthesis_fkey
# 16     uuid          NO                                      Operator_pkey
# 17  varchar          NO                                               None
# 18  varchar          NO                                               None
# 19     uuid         YES  Product_Characterization_id_characterization_fkey
# 20     uuid          NO                      Product_Characterization_pkey
# 21     uuid         YES         Product_Characterization_id_synthesis_fkey
# 22     uuid          NO                                       Reagent_pkey
# 23     uuid         YES                           Reagent_id_compound_fkey
# 24   float8         YES                                               None
# 25  varchar         YES                                               None
# 26   float8         YES                                               None
# 27  varchar         YES                                               None
# 28     uuid         YES                      Synthesis_id_data_source_fkey
# 29     uuid          NO                                     Synthesis_pkey
# 30   float8         YES                                               None
# 31   float8         YES                                               None
# 32   float8         YES                                               None
# 33   float8         YES                                               None
# 34     uuid         YES                Synthesis_Compound_id_compound_fkey
# 35     uuid         YES               Synthesis_Compound_id_synthesis_fkey
# 36     uuid          NO                            Synthesis_Compound_pkey
#
#    containt_type                                         references
# 0           None               Characterization.id_characterization
# 1           None                                               None
# 2           None                                               None
# 3           None                                               None
# 4           None                                               None
# 5           None                               Compound.id_compound
# 6           None                                               None
# 7           None                                               None
# 8           None                         Data_source.id_data_source
# 9           None                                               None
# 10          None                                               None
# 11          None                                               None
# 12          None                                               None
# 13          None                           Experiment.id_experiment
# 14          None                               Operator.id_operator
# 15          None                             Synthesis.id_synthesis
# 16          None                               Operator.id_operator
# 17          None                                               None
# 18          None                                               None
# 19          None               Characterization.id_characterization
# 20          None  Product_Characterization.id_product_characteri...
# 21          None                             Synthesis.id_synthesis
# 22          None                        Reagent.id_characterization
# 23          None                               Compound.id_compound
# 24          None                                               None
# 25          None                                               None
# 26          None                                               None
# 27          None                                               None
# 28          None                         Data_source.id_data_source
# 29          None                             Synthesis.id_synthesis
# 30          None                                               None
# 31          None                                               None
# 32          None                                               None
# 33          None                                               None
# 34          None                               Compound.id_compound
# 35          None                             Synthesis.id_synthesis
# 36          None           Synthesis_Compound.id_synthesis_compound

# %%
#admin_client.remove_database('stober_db')

# %%
user_client.get_alembic_revisions()
# Out:
#        revision                                          log_entry  \
# 0  0bc99b5f8fcc  Rev: 0bc99b5f8fcc (head)\nParent: f31c7d486f1f...
# 1  311e0c050706  Rev: 311e0c050706 (head)\nParent: bf3c5d811155...
# 2  bd3280dd67dc  Rev: bd3280dd67dc (head)\nParent: f31c7d486f1f...
#
#                          branch_labels
# 0            [eventsourcing, compchem]
# 1                         [molar-main]
# 2  [stober_db_creation, eventsourcing]

# %%
data = admin_stober.create_entry(
    type="Operator",
    data={
        "id_operator":2,
    }
)
data
# Out:
# ---------------------------------------------------------------------------
# MolarBackendError                         Traceback (most recent call last)
# /tmp/ipykernel_6862/1750056089.py in <module>
#       2     type="Operator",
#       3     data={
# ----> 4         "id_operator":2,
#       5     }
#       6 )
#
# ~/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/molar/client.py in create_entry(self, type, data)
#     240             json=datum,
#     241             headers=self.headers,
# --> 242             return_pandas_dataframe=False,
#     243         )
#     244
#
# ~/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/molar/client.py in request(self, url, method, params, json, data, headers, return_pandas_dataframe)
#      97         if response.status_code != 200:
#      98             raise MolarBackendError(
# ---> 99                 status_code=response.status_code, message=out["detail"]
#     100             )
#     101
#
# MolarBackendError: The client got an unexpected answer from the backend:
# 403: Could not validate credentials

# %%
import sqlalchemy as sa

# %%
eng = sa.create_engine("mysql://belu:belu@localhost/main")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6862/1141781729.py in <module>
# ----> 1 eng = sa.create_engine("mysql://belu:belu@localhost/main")
#
# <string> in create_engine(url, **kwargs)
#
# ~/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     558             if k in kwargs:
#     559                 dbapi_args[k] = pop_kwarg(k)
# --> 560         dbapi = dialect_cls.dbapi(**dbapi_args)
#     561
#     562     dialect_args["dbapi"] = dbapi
#
# ~/.local/share/virtualenvs/acceleration-consortium-hackaton-VkvLMKVg/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in dbapi(cls)
#     165     @classmethod
#     166     def dbapi(cls):
# --> 167         return __import__("MySQLdb")
#     168
#     169     def on_connect(self):
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
admin_stober.view_entries("stober_db")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
es = admin_stober.view_entries()
es
# Out:
# Empty DataFrame
# Columns: []
# Index: []
